# %%
#Import pacakges
import pandas as pd
#import numpy as np
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
from statsmodels.formula.api import ols
from scipy.stats import pearsonr, normaltest

import warnings
warnings.filterwarnings('ignore')

# %%
#Load cleaned_dark_chocolate_bar_ratings data into data frame
df_r = pd.read_csv('cleaned_dark_chocolate_bar_ratings.csv')
df_rating = df_r[['bean_country', 'cocoa_percent', 'total_ingredients','ingredient_combination','rating']].copy()
#df_rating.info()

#Load individual_characteristics data into data frame
df_c = pd.read_csv('individual_characteristics.csv')
df_char = df_c[['characteristic','rating']].copy()
#df_char.info()

# %% [markdown]
# # Test Statistical Significance
# ***
# ## Test for Normality
# Before testing for statistical significance in the dataset, I tested for normality in the quantitative data to determine if I need to use parametric or non-parametric tests (Bhandari, 2020).

# %%
#Test Normality of 'rating'
k2, p = normaltest(df_rating['rating'])
alpha = 0.05
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis for rating can be rejected.")
else:
    print("The null hypothesis for rating cannot be rejected.")
# Out:
# p = 1.46487e-14
# The null hypothesis for rating can be rejected.

# %%
#Test Normality of 'total_ingredients'
k2, p = normaltest(df_rating['total_ingredients'])
alpha = 0.05
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis for total_ingredients can be rejected.")
else:
    print("The null hypothesis for total_ingredients cannot be rejected.")
# Out:
# p = 9.33989e-29
# The null hypothesis for total_ingredients can be rejected.

# %%
#Test Normality of 'cocoa_percent'
k2, p = normaltest(df_rating['cocoa_percent'])
alpha = 0.05
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis for cocoa_percent can be rejected.")
else:
    print("The null hypothesis for cocoa_percent cannot be rejected.")
# Out:
# p = 1.19052e-78
# The null hypothesis for cocoa_percent can be rejected.

# %% [markdown]
# Because I can reject the null hypothesis for each quantitative variable, I will use parametric tests for statistical significance.

# %% [markdown]
# ## Testing Statistical Significance
# To test statistical significance in the dataset, I will be using the ANOVA test for categorical explanatory variables and Pearson's R for quantitative data.

# %% [markdown]
# ### Statistical Significance for Categorical Data using ANOVA

# %%
#ANOVA test for 'memorable_characteristics'
anova_df = df_char[['rating', 'characteristic']].dropna()

relate_df = df_char[['rating', 'characteristic']]
anova = smf.ols(formula='rating ~ C(characteristic)', data=relate_df).fit()

anova.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     4.047
# Date:                Wed, 07 Apr 2021   Prob (F-statistic):          1.16e-195
# Time:                        11:46:13   Log-Likelihood:                -2367.2
# No. Observations:                6398   AIC:                             6196.
# Df Residuals:                    5667   BIC:                         1.114e+04
# Df Model:                         730
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               3.2500      0.372      8.732      0.000       2.520       3.980
# C(characteristic)[T.accessible]                         0.1250      0.416      0.300      0.764      -0.691       0.941
# C(characteristic)[T.acidic]                            -0.0764      0.377     -0.202      0.840      -0.816       0.663
# C(characteristic)[T.alcohol]                        -2.115e-12      0.430  -4.92e-12      1.000      -0.843       0.843
# C(characteristic)[T.alkalized note]                    -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.alluring aroma]                     0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.almond]                             0.2500      0.456      0.548      0.583      -0.644       1.144
# C(characteristic)[T.almond butter]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.almost burnt]                      -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.aluminum]                          -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.ambiguous]                         -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.anise]                              0.1500      0.408      0.368      0.713      -0.649       0.949
# C(characteristic)[T.appealing smoke]                    0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.apple]                              0.3750      0.456      0.823      0.411      -0.519       1.269
# C(characteristic)[T.artificial]                        -0.2500      0.456     -0.548      0.583      -1.144       0.644
# C(characteristic)[T.ashy]                              -0.5417      0.387     -1.398      0.162      -1.301       0.218
# C(characteristic)[T.assertive]                          0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.astringent]                        -0.1912      0.378     -0.506      0.613      -0.932       0.549
# C(characteristic)[T.atypical]                          -0.3750      0.456     -0.823      0.411      -1.269       0.519
# C(characteristic)[T.baked]                             -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.baked bread]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.balanced]                           0.4844      0.384      1.262      0.207      -0.268       1.237
# C(characteristic)[T.banana]                             0.1250      0.376      0.332      0.740      -0.613       0.863
# C(characteristic)[T.banana cream]                      -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.banana nut]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.banana raspberry]                   0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.base cocoa]                        -0.0625      0.416     -0.150      0.881      -0.878       0.753
# C(characteristic)[T.base cocoa ]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.basic]                             -0.0833      0.402     -0.207      0.836      -0.871       0.705
# C(characteristic)[T.basic chocolate]                    0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.basic cocoa]                       -0.0341      0.381     -0.090      0.929      -0.780       0.712
# C(characteristic)[T.basic cocoa base]               -2.054e-12      0.526   -3.9e-12      1.000      -1.032       1.032
# C(characteristic)[T.berry]                              0.0568      0.381      0.149      0.881      -0.689       0.803
# C(characteristic)[T.berry note]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.berry note ]                     -1.89e-12      0.526  -3.59e-12      1.000      -1.032       1.032
# C(characteristic)[T.bitter]                            -0.4598      0.376     -1.224      0.221      -1.196       0.276
# C(characteristic)[T.bitter aftertaste]                  0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.bitter coffee flavor]              -1.2500      0.526     -2.375      0.018      -2.282      -0.218
# C(characteristic)[T.bitter dominant]                   -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.bitter end]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.bitter then nut rustic]            -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.black current]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.black licorice]                    -0.0250      0.390     -0.064      0.949      -0.790       0.740
# C(characteristic)[T.black pepper]                       0.0481      0.379      0.127      0.899      -0.696       0.792
# C(characteristic)[T.black tea]                          0.0833      0.430      0.194      0.846      -0.759       0.926
# C(characteristic)[T.blackberry]                         0.3864      0.389      0.994      0.320      -0.376       1.148
# C(characteristic)[T.bland]                             -0.2639      0.382     -0.690      0.490      -1.014       0.486
# C(characteristic)[T.blueberry]                          0.2500      0.395      0.633      0.527      -0.524       1.024
# C(characteristic)[T.bold]                               0.0658      0.382      0.172      0.863      -0.683       0.814
# C(characteristic)[T.bold cherry]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.bold citrus]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.bold olive]                     -1.899e-12      0.526  -3.61e-12      1.000      -1.032       1.032
# C(characteristic)[T.bourbon]                            0.1136      0.389      0.292      0.770      -0.648       0.876
# C(characteristic)[T.brandy]                            -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.bread]                             -0.0833      0.392     -0.212      0.832      -0.852       0.686
# C(characteristic)[T.bread note]                     -2.082e-12      0.526  -3.96e-12      1.000      -1.032       1.032
# C(characteristic)[T.brief fruit note]                  -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.bright]                             0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.bright berry]                      -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.bright fruit]                       0.2500      0.386      0.647      0.518      -0.507       1.007
# C(characteristic)[T.bright red]                      -2.14e-12      0.456  -4.69e-12      1.000      -0.894       0.894
# C(characteristic)[T.bright red fruit]                   0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.brownie]                            0.0833      0.377      0.221      0.825      -0.655       0.822
# C(characteristic)[T.brownie batter]                     0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.brownie mix]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.burlap]                            -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.burn]                              -0.5625      0.416     -1.352      0.177      -1.378       0.253
# C(characteristic)[T.burn sensation]                 -2.032e-12      0.526  -3.86e-12      1.000      -1.032       1.032
# C(characteristic)[T.burnt]                             -0.5476      0.381     -1.437      0.151      -1.294       0.199
# C(characteristic)[T.burnt black licorice]           -2.266e-12      0.526   -4.3e-12      1.000      -1.032       1.032
# C(characteristic)[T.burnt black pepper]             -2.034e-12      0.526  -3.86e-12      1.000      -1.032       1.032
# C(characteristic)[T.burnt brownie]                      0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.burnt butterscotch]                -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.burnt caramel]                      0.1875      0.416      0.451      0.652      -0.628       1.003
# C(characteristic)[T.burnt cinnamon]                     0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.burnt cocoa]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.burnt coffee]                      -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.burnt edge]                        -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.burnt fuel]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.burnt honey]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.burnt molasses]                    -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.burnt nut]                         -0.3125      0.416     -0.751      0.453      -1.128       0.503
# C(characteristic)[T.burnt rubber]                      -0.6000      0.408     -1.472      0.141      -1.399       0.199
# C(characteristic)[T.burnt up front]                    -1.0000      0.526     -1.900      0.058      -2.032       0.032
# C(characteristic)[T.burnt wood]                        -0.5000      0.456     -1.097      0.273      -1.394       0.394
# C(characteristic)[T.butter]                            -0.2308      0.386     -0.597      0.550      -0.988       0.526
# C(characteristic)[T.butterscotch]                       0.2692      0.386      0.697      0.486      -0.488       1.026
# C(characteristic)[T.cadbury egg]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.candied]                            0.0714      0.398      0.180      0.858      -0.709       0.851
# C(characteristic)[T.candy]                             -0.3500      0.408     -0.858      0.391      -1.149       0.449
# C(characteristic)[T.candy flavor]                       0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.candy spice]                    -2.105e-12      0.456  -4.62e-12      1.000      -0.894       0.894
# C(characteristic)[T.candy tart]                     -2.243e-12      0.526  -4.26e-12      1.000      -1.032       1.032
# C(characteristic)[T.caramel]                            0.0746      0.375      0.199      0.843      -0.661       0.811
# C(characteristic)[T.cardamom]                           0.0625      0.416      0.150      0.881      -0.753       0.878
# C(characteristic)[T.cardboard]                         -0.5385      0.386     -1.394      0.163      -1.296       0.219
# C(characteristic)[T.carrots]                        -2.211e-12      0.526   -4.2e-12      1.000      -1.032       1.032
# C(characteristic)[T.cashew]                             0.3333      0.430      0.776      0.438      -0.509       1.176
# C(characteristic)[T.chalky]                            -0.3889      0.382     -1.017      0.309      -1.139       0.361
# C(characteristic)[T.charcoal]                           0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.cheesy]                            -0.2250      0.390     -0.576      0.564      -0.990       0.540
# C(characteristic)[T.cheesy off flavor]                 -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.chemical]                          -0.7500      0.384     -1.951      0.051      -1.504       0.004
# C(characteristic)[T.chemical off]                      -0.6250      0.456     -1.371      0.170      -1.519       0.269
# C(characteristic)[T.chemical off note]                 -0.6250      0.456     -1.371      0.170      -1.519       0.269
# C(characteristic)[T.chemical or burnt note]            -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.cherry]                             0.2429      0.377      0.643      0.520      -0.497       0.983
# C(characteristic)[T.chewy]                              0.0208      0.387      0.054      0.957      -0.739       0.780
# C(characteristic)[T.chlorine]                          -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.chocolate]                          0.1833      0.384      0.477      0.633      -0.570       0.937
# C(characteristic)[T.chocolate base off]                -1.2500      0.526     -2.375      0.018      -2.282      -0.218
# C(characteristic)[T.chocolate covered banana]           0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.chocolate covered cherry]           0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.chocolate covered strawberry]       0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.chocolate ice cream]                0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.chocolate pudding]                  0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.chunky]                             0.0357      0.398      0.090      0.928      -0.744       0.816
# C(characteristic)[T.chunky melt]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.cigar]                              0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.cigarette butt]                    -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.cinnamon]                           0.2045      0.389      0.526      0.599      -0.558       0.967
# C(characteristic)[T.citrus]                             0.1087      0.380      0.286      0.775      -0.637       0.854
# C(characteristic)[T.classic]                            0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.clingy]                            -0.6250      0.456     -1.371      0.170      -1.519       0.269
# C(characteristic)[T.clove]                              0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.cloying]                           -0.6667      0.430     -1.551      0.121      -1.509       0.176
# C(characteristic)[T.coarse]                            -0.1100      0.380     -0.290      0.772      -0.854       0.634
# C(characteristic)[T.cocoa]                              0.1422      0.373      0.381      0.703      -0.589       0.874
# C(characteristic)[T.cocoa base]                        -0.1667      0.402     -0.415      0.678      -0.955       0.621
# C(characteristic)[T.cocoa butter dominant]             -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.cocoa dominant]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.cocoa flavor dominant]          -2.075e-12      0.526  -3.94e-12      1.000      -1.032       1.032
# C(characteristic)[T.coconut]                           -0.0694      0.382     -0.182      0.856      -0.819       0.680
# C(characteristic)[T.coffee]                             0.0286      0.375      0.076      0.939      -0.706       0.763
# C(characteristic)[T.coffee grounds]                 -2.172e-12      0.456  -4.76e-12      1.000      -0.894       0.894
# C(characteristic)[T.coffee note]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.coffee note from roast]            -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.complex]                            0.3125      0.376      0.831      0.406      -0.425       1.050
# C(characteristic)[T.controlled bitter]                  0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.cooked banana]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.cooling sensation]                 -0.1250      0.456     -0.274      0.784      -1.019       0.769
# C(characteristic)[T.cough medicine]                    -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.cranberry]                          0.5000      0.456      1.097      0.273      -0.394       1.394
# C(characteristic)[T.cream]                              0.2857      0.398      0.718      0.473      -0.494       1.066
# C(characteristic)[T.creamy]                             0.2296      0.373      0.615      0.538      -0.502       0.961
# C(characteristic)[T.crisp nibs]                        -0.3750      0.456     -0.823      0.411      -1.269       0.519
# C(characteristic)[T.crumbly]                           -0.6250      0.456     -1.371      0.170      -1.519       0.269
# C(characteristic)[T.crunchy]                            0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.cucumber]                          -0.1250      0.456     -0.274      0.784      -1.019       0.769
# C(characteristic)[T.dairy]                              0.0756      0.377      0.201      0.841      -0.663       0.814
# C(characteristic)[T.damp wood]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dark berry]                         0.3667      0.384      0.954      0.340      -0.387       1.120
# C(characteristic)[T.dark cocoa]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.dark coffee]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dark color]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.dark forest berry]                  0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.dark roast]                         0.1667      0.430      0.388      0.698      -0.676       1.009
# C(characteristic)[T.dark wood]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dates]                             -0.2500      0.456     -0.548      0.583      -1.144       0.644
# C(characteristic)[T.deep]                               0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.deep cherry]                    -1.953e-12      0.526  -3.71e-12      1.000      -1.032       1.032
# C(characteristic)[T.deep chocolate]                     0.3333      0.430      0.776      0.438      -0.509       1.176
# C(characteristic)[T.deep cocoa]                         0.2250      0.390      0.576      0.564      -0.540       0.990
# C(characteristic)[T.delicate]                           0.4000      0.390      1.025      0.306      -0.365       1.165
# C(characteristic)[T.delicate cocoa]                     0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.delicate fruit]                     0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.dense]                              0.6250      0.456      1.371      0.170      -0.269       1.519
# C(characteristic)[T.diluted]                            0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.dirt]                              -0.4439      0.378     -1.175      0.240      -1.185       0.297
# C(characteristic)[T.distinct]                           0.5833      0.430      1.357      0.175      -0.259       1.426
# C(characteristic)[T.distinct lemon]                     0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.distinct spice]                 -2.041e-12      0.526  -3.88e-12      1.000      -1.032       1.032
# C(characteristic)[T.dominant by heavy roast]           -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dominant hazelnut]              -1.997e-12      0.526  -3.79e-12      1.000      -1.032       1.032
# C(characteristic)[T.dominant off note]                 -1.5000      0.526     -2.850      0.004      -2.532      -0.468
# C(characteristic)[T.dominant roast]                 -2.067e-12      0.456  -4.53e-12      1.000      -0.894       0.894
# C(characteristic)[T.dominant savory]                -1.939e-12      0.526  -3.68e-12      1.000      -1.032       1.032
# C(characteristic)[T.dominant spice]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.dominant tobacco]                  -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dried fig]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dried fruit]                        0.1706      0.375      0.455      0.649      -0.565       0.906
# C(characteristic)[T.dried sour fruit]                  -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.dry]                               -0.3136      0.375     -0.835      0.404      -1.049       0.422
# C(characteristic)[T.dull]                              -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.dutched?]                          -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.earth]                             -0.2071      0.373     -0.555      0.579      -0.939       0.525
# C(characteristic)[T.earth end]                         -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.earth green]                    -2.219e-12      0.526  -4.22e-12      1.000      -1.032       1.032
# C(characteristic)[T.earth off note]                    -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.easter candy]                      -0.5000      0.456     -1.097      0.273      -1.394       0.394
# C(characteristic)[T.easy melt]                          0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.empty]                             -0.2500      0.456     -0.548      0.583      -1.144       0.644
# C(characteristic)[T.ends sour]                      -2.185e-12      0.526  -4.15e-12      1.000      -1.032       1.032
# C(characteristic)[T.evolves black pepper to citrus]     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.fades fast]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.faint cinnamon]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.fall spice]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.fatty]                             -0.1809      0.373     -0.484      0.628      -0.913       0.551
# C(characteristic)[T.fatty residue]                     -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.fertilizer]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.few grits]                         -0.1042      0.387     -0.269      0.788      -0.864       0.655
# C(characteristic)[T.fig]                                0.2885      0.386      0.747      0.455      -0.469       1.046
# C(characteristic)[T.fig note]                           0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.flat]                              -0.4038      0.386     -1.046      0.296      -1.161       0.353
# C(characteristic)[T.flat flavor]                       -1.2500      0.526     -2.375      0.018      -2.282      -0.218
# C(characteristic)[T.floral]                             0.0044      0.374      0.012      0.991      -0.728       0.737
# C(characteristic)[T.floral note]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.floral-spice mix]                   0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.flour]                             -0.3750      0.456     -0.823      0.411      -1.269       0.519
# C(characteristic)[T.fragrant]                       -2.136e-12      0.416  -5.13e-12      1.000      -0.816       0.816
# C(characteristic)[T.fresh grape]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.fresh nibs]                        -0.6250      0.456     -1.371      0.170      -1.519       0.269
# C(characteristic)[T.fruit]                              0.0394      0.374      0.105      0.916      -0.693       0.772
# C(characteristic)[T.fruit ]                             0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.fruit forward]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.fruit medley]                      -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.fruit note]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.fruit punch]                       -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.fruit then nut]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.fudge]                              0.1111      0.392      0.283      0.777      -0.658       0.880
# C(characteristic)[T.fudge then spicy]               -2.216e-12      0.526  -4.21e-12      1.000      -1.032       1.032
# C(characteristic)[T.fuel]                              -0.6250      0.402     -1.555      0.120      -1.413       0.163
# C(characteristic)[T.full bodied]                        0.4167      0.430      0.969      0.332      -0.426       1.259
# C(characteristic)[T.full cocoa flavor]                  0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.full flavor spectrum]               0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.fungal]                            -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.gateway]                            0.2187      0.395      0.554      0.580      -0.555       0.993
# C(characteristic)[T.gentle roast]                       0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.ginger]                            -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.grainy]                            -0.2143      0.398     -0.539      0.590      -0.994       0.566
# C(characteristic)[T.grainy texture]                 -2.164e-12      0.456  -4.75e-12      1.000      -0.894       0.894
# C(characteristic)[T.grape]                              0.1613      0.378      0.427      0.670      -0.580       0.903
# C(characteristic)[T.grapefruit]                         0.3750      0.456      0.823      0.411      -0.519       1.269
# C(characteristic)[T.grass]                             -0.0238      0.375     -0.063      0.949      -0.759       0.712
# C(characteristic)[T.green]                             -0.0921      0.382     -0.241      0.809      -0.841       0.657
# C(characteristic)[T.green apple]                        0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.green fruit]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.green mint]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.grits]                             -0.2778      0.392     -0.708      0.479      -1.047       0.491
# C(characteristic)[T.gritty]                            -0.3051      0.375     -0.814      0.416      -1.040       0.430
# C(characteristic)[T.gummy]                             -0.1250      0.395     -0.317      0.752      -0.899       0.649
# C(characteristic)[T.ham]                               -0.2321      0.377     -0.616      0.538      -0.970       0.506
# C(characteristic)[T.harsh]                             -0.5556      0.392     -1.416      0.157      -1.325       0.214
# C(characteristic)[T.harsh aroma]                       -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.harsh burnt]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.harsh end]                      -1.853e-12      0.526  -3.52e-12      1.000      -1.032       1.032
# C(characteristic)[T.harsh flavor]                      -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.harsh smoke]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.harsh wood]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.hay]                               -0.0417      0.402     -0.104      0.917      -0.830       0.746
# C(characteristic)[T.hazelnut]                           0.3125      0.395      0.792      0.429      -0.461       1.086
# C(characteristic)[T.heavy roast]                        0.0469      0.384      0.122      0.903      -0.705       0.799
# C(characteristic)[T.heavy smoke]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.herb]                               0.1136      0.389      0.292      0.770      -0.648       0.876
# C(characteristic)[T.high acid]                       -1.93e-12      0.526  -3.67e-12      1.000      -1.032       1.032
# C(characteristic)[T.high acidity]                      -0.0556      0.392     -0.142      0.887      -0.825       0.714
# C(characteristic)[T.high astringent]                   -0.1389      0.392     -0.354      0.723      -0.908       0.630
# C(characteristic)[T.high roast]                        -0.1136      0.389     -0.292      0.770      -0.876       0.648
# C(characteristic)[T.hint of anise]                      0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.hint of berry]                     -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.hint of fruit]                     -0.4375      0.416     -1.051      0.293      -1.253       0.378
# C(characteristic)[T.hint of smoke]                     -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.hint of tang]                   -2.261e-12      0.526  -4.29e-12      1.000      -1.032       1.032
# C(characteristic)[T.holiday spice]                  -2.148e-12      0.526  -4.08e-12      1.000      -1.032       1.032
# C(characteristic)[T.homey]                              0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.honey]                              0.1696      0.379      0.448      0.654      -0.573       0.912
# C(characteristic)[T.hot cocoa]                         -0.1000      0.408     -0.245      0.806      -0.899       0.699
# C(characteristic)[T.hot spice]                      -2.164e-12      0.430  -5.04e-12      1.000      -0.843       0.843
# C(characteristic)[T.intense]                           -0.0759      0.374     -0.203      0.839      -0.808       0.656
# C(characteristic)[T.intense banana]                     0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.intense bitter]                    -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.intense blueberry]              -2.032e-12      0.526  -3.86e-12      1.000      -1.032       1.032
# C(characteristic)[T.intense brownie]                    0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.intense cocoa]                     -0.0833      0.430     -0.194      0.846      -0.926       0.759
# C(characteristic)[T.intense coffee]                    -1.0000      0.526     -1.900      0.058      -2.032       0.032
# C(characteristic)[T.intense earth]                     -0.1250      0.456     -0.274      0.784      -1.019       0.769
# C(characteristic)[T.intense floral]                    -0.0833      0.430     -0.194      0.846      -0.926       0.759
# C(characteristic)[T.intense fruit]                  -2.015e-12      0.456  -4.42e-12      1.000      -0.894       0.894
# C(characteristic)[T.intense grape]                      0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.intense marshmallow]                0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.intense mocha flavor]               0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.intense olive]                   -2.16e-12      0.526   -4.1e-12      1.000      -1.032       1.032
# C(characteristic)[T.intense orange]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.intense pepper]                     0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.intense plum]                       0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.intense prune]                      0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.intense smoke]                     -0.3125      0.416     -0.751      0.453      -1.128       0.503
# C(characteristic)[T.intense spice]                     -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.intense spicy]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.intense sweet]                  -2.118e-12      0.526  -4.02e-12      1.000      -1.032       1.032
# C(characteristic)[T.intense tangerine]                  0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.intense tart]                   -2.058e-12      0.526  -3.91e-12      1.000      -1.032       1.032
# C(characteristic)[T.intense vanilla]                   -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.intense vinegar]                   -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.large grits]                       -0.2083      0.402     -0.518      0.604      -0.996       0.580
# C(characteristic)[T.large nibs]                         0.3750      0.456      0.823      0.411      -0.519       1.269
# C(characteristic)[T.large unground pieces]          -2.023e-12      0.526  -3.84e-12      1.000      -1.032       1.032
# C(characteristic)[T.late chocolate]                 -2.252e-12      0.526  -4.28e-12      1.000      -1.032       1.032
# C(characteristic)[T.late cocoa]                        -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.late cocoa note]                   -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.late ham]                       -2.152e-12      0.526  -4.09e-12      1.000      -1.032       1.032
# C(characteristic)[T.late sour]                      -2.204e-12      0.408   -5.4e-12      1.000      -0.799       0.799
# C(characteristic)[T.late sour ]                        -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.late spice]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.late tart]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.late tart note]                    -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.lavender]                       -2.001e-12      0.526   -3.8e-12      1.000      -1.032       1.032
# C(characteristic)[T.leafy]                              0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.leather]                           -0.3152      0.380     -0.829      0.407      -1.061       0.430
# C(characteristic)[T.leather flavor]                    -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.lemon]                              0.0147      0.383      0.038      0.969      -0.736       0.766
# C(characteristic)[T.less intense berry]                 0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.licorice]                          -0.0469      0.384     -0.122      0.903      -0.799       0.705
# C(characteristic)[T.light brown]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.light cocoa]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.light color]                       -0.0385      0.386     -0.100      0.921      -0.796       0.719
# C(characteristic)[T.light lime]                        -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.light perfume]                     -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.light roast]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.light rum]                          0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.light toffee]                   -2.003e-12      0.526   -3.8e-12      1.000      -1.032       1.032
# C(characteristic)[T.like brownie]                    -1.99e-12      0.526  -3.78e-12      1.000      -1.032       1.032
# C(characteristic)[T.like candy]                        -0.3125      0.395     -0.792      0.429      -1.086       0.461
# C(characteristic)[T.like candy off flavor]             -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.like candy vanilla]                -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.like melon]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.like tea]                          -0.1250      0.456     -0.274      0.784      -1.019       0.769
# C(characteristic)[T.lime]                               0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.lingering coffee]                   0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.long]                               0.3333      0.387      0.860      0.390      -0.426       1.093
# C(characteristic)[T.long lasting]                       0.3750      0.402      0.933      0.351      -0.413       1.163
# C(characteristic)[T.low refinement]                    -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.macadamia]                      -1.954e-12      0.526  -3.71e-12      1.000      -1.032       1.032
# C(characteristic)[T.malt]                               0.3333      0.402      0.829      0.407      -0.455       1.121
# C(characteristic)[T.maltitol]                          -1.2500      0.526     -2.375      0.018      -2.282      -0.218
# C(characteristic)[T.maple]                              0.1250      0.416      0.300      0.764      -0.691       0.941
# C(characteristic)[T.marshmallow]                        0.0341      0.381      0.090      0.929      -0.712       0.780
# C(characteristic)[T.masculine]                          0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mass market]                       -0.5000      0.456     -1.097      0.273      -1.394       0.394
# C(characteristic)[T.meaty]                             -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.medicinal]                         -0.7031      0.384     -1.833      0.067      -1.455       0.049
# C(characteristic)[T.medium roast]                       0.2500      0.456      0.548      0.583      -0.644       1.144
# C(characteristic)[T.medium roasted cocoa]           -1.982e-12      0.526  -3.77e-12      1.000      -1.032       1.032
# C(characteristic)[T.mellow]                             0.3500      0.408      0.858      0.391      -0.449       1.149
# C(characteristic)[T.mellow but flavorful]               0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mellow chocolate]                   0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mellow fruit]                       0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.melon]                              0.1458      0.380      0.384      0.701      -0.599       0.891
# C(characteristic)[T.melon floral]                      -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.melon note]                        -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.menthol]                           -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.metal]                             -0.4779      0.378     -1.266      0.206      -1.218       0.262
# C(characteristic)[T.metal edge]                        -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.mild]                               0.1136      0.389      0.292      0.770      -0.648       0.876
# C(characteristic)[T.mild anise]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.mild ashy]                          0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mild banana]                       -0.2500      0.456     -0.548      0.583      -1.144       0.644
# C(characteristic)[T.mild berry]                     -2.123e-12      0.526  -4.03e-12      1.000      -1.032       1.032
# C(characteristic)[T.mild bitter]                       -0.0982      0.379     -0.259      0.795      -0.841       0.644
# C(characteristic)[T.mild burn]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.mild burnt]                        -0.2500      0.456     -0.548      0.583      -1.144       0.644
# C(characteristic)[T.mild burnt caramel]             -2.104e-12      0.526     -4e-12      1.000      -1.032       1.032
# C(characteristic)[T.mild cacao]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.mild caramel]                       0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mild cherry]                        0.1875      0.416      0.451      0.652      -0.628       1.003
# C(characteristic)[T.mild chocolate]                     0.1667      0.430      0.388      0.698      -0.676       1.009
# C(characteristic)[T.mild chocolate ]                   -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.mild citrus]                       -0.1250      0.416     -0.300      0.764      -0.941       0.691
# C(characteristic)[T.mild cocoa]                     -2.109e-12      0.390   -5.4e-12      1.000      -0.765       0.765
# C(characteristic)[T.mild coffee]                        0.0833      0.402      0.207      0.836      -0.705       0.871
# C(characteristic)[T.mild dairy]                     -2.025e-12      0.526  -3.85e-12      1.000      -1.032       1.032
# C(characteristic)[T.mild dried fruit]                   0.2500      0.456      0.548      0.583      -0.644       1.144
# C(characteristic)[T.mild earth]                     -2.046e-12      0.456  -4.49e-12      1.000      -0.894       0.894
# C(characteristic)[T.mild fatty]                         0.0833      0.430      0.194      0.846      -0.759       0.926
# C(characteristic)[T.mild flavors]                       0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.mild floral]                    -2.062e-12      0.416  -4.96e-12      1.000      -0.816       0.816
# C(characteristic)[T.mild fruit]                        -0.1250      0.378     -0.330      0.741      -0.867       0.617
# C(characteristic)[T.mild fruit ]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mild grape]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.mild ham]                           0.0625      0.416      0.150      0.881      -0.753       0.878
# C(characteristic)[T.mild honey]                     -2.133e-12      0.430  -4.96e-12      1.000      -0.843       0.843
# C(characteristic)[T.mild intense]                       0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mild lemon]                         0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.mild licorice]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.mild marshmallow]                  -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.mild metal]                        -0.1071      0.398     -0.269      0.788      -0.887       0.673
# C(characteristic)[T.mild mint]                          0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.mild molasses]                  -2.103e-12      0.430  -4.89e-12      1.000      -0.843       0.843
# C(characteristic)[T.mild musty]                     -2.114e-12      0.526  -4.02e-12      1.000      -1.032       1.032
# ...
# C(characteristic)[T.sour tang]                         -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.sour vegetal]                       0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.soy]                                0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.spice]                              0.1212      0.375      0.323      0.747      -0.614       0.856
# C(characteristic)[T.spicy]                              0.0668      0.374      0.179      0.858      -0.666       0.799
# C(characteristic)[T.spicy cinnamon]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.spicy edge]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.spicy mild molasses]                0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.spicy pepper]                       0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.spoiled]                           -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.spoiled milk]                   -2.082e-12      0.526  -3.96e-12      1.000      -1.032       1.032
# C(characteristic)[T.sticky]                            -0.0801      0.375     -0.214      0.831      -0.814       0.654
# C(characteristic)[T.strawberry]                         0.2019      0.379      0.532      0.595      -0.542       0.946
# C(characteristic)[T.strong]                            -0.3333      0.430     -0.776      0.438      -1.176       0.509
# C(characteristic)[T.strong base cocoa]              -2.096e-12      0.526  -3.98e-12      1.000      -1.032       1.032
# C(characteristic)[T.strong bitter]                     -0.5000      0.456     -1.097      0.273      -1.394       0.394
# C(characteristic)[T.strong chemical]                   -1.7500      0.526     -3.325      0.001      -2.782      -0.718
# C(characteristic)[T.strong chocolate]                   0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.strong cocoa]                       0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.strong coffee]                     -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.strong floral]                      0.1500      0.408      0.368      0.713      -0.649       0.949
# C(characteristic)[T.strong fruit]                       0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.strong malt]                        0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.strong molasses]                -2.102e-12      0.526  -3.99e-12      1.000      -1.032       1.032
# C(characteristic)[T.strong nut]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.strong nut ]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.strong off flavor]                 -2.2500      0.526     -4.274      0.000      -3.282      -1.218
# C(characteristic)[T.strong pepper]                     -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.strong raspberry]                   0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.strong rubber]                     -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.strong smoke]                   -2.134e-12      0.526  -4.05e-12      1.000      -1.032       1.032
# C(characteristic)[T.strong smoke tobacco]              -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.strong sour]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.strong spice]                       0.3333      0.430      0.776      0.438      -0.509       1.176
# C(characteristic)[T.strong vanilla]                    -0.6364      0.389     -1.637      0.102      -1.398       0.126
# C(characteristic)[T.strong wine]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.subdued]                           -0.0833      0.430     -0.194      0.846      -0.926       0.759
# C(characteristic)[T.subtle]                             0.3571      0.398      0.898      0.369      -0.423       1.137
# C(characteristic)[T.subtle but refreshing]              0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.subtle dairy]                      -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.subtle fruit]                   -2.111e-12      0.526  -4.01e-12      1.000      -1.032       1.032
# C(characteristic)[T.subtle grape note]                  0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.subtle red berry]                   0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.subtle strawberry]                 -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.sugar]                             -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.sugar dominant]                    -0.2500      0.456     -0.548      0.583      -1.144       0.644
# C(characteristic)[T.sunflower]                          0.2500      0.430      0.582      0.561      -0.593       1.093
# C(characteristic)[T.super temper]                      -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.surface mark]                      -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.sweet]                             -0.2045      0.373     -0.548      0.583      -0.936       0.527
# C(characteristic)[T.sweet cocoa]                        0.2500      0.456      0.548      0.583      -0.644       1.144
# C(characteristic)[T.sweet edge]                         0.0250      0.390      0.064      0.949      -0.740       0.790
# C(characteristic)[T.sweet grass]                       -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.sweet spice]                        0.5000      0.456      1.097      0.273      -0.394       1.394
# C(characteristic)[T.swiss miss]                        -0.5000      0.430     -1.163      0.245      -1.343       0.343
# C(characteristic)[T.synthetic]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.tang]                              -0.0795      0.381     -0.209      0.834      -0.826       0.667
# C(characteristic)[T.tang wine]                          0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.tangerine]                          0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.tannic]                             0.1071      0.398      0.269      0.788      -0.673       0.887
# C(characteristic)[T.tart]                               0.0223      0.376      0.059      0.953      -0.714       0.758
# C(characteristic)[T.tart citrus]                        0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.tart fruit]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.tart red berry]                     0.3750      0.456      0.823      0.411      -0.519       1.269
# C(characteristic)[T.tea]                                0.0455      0.389      0.117      0.907      -0.717       0.808
# C(characteristic)[T.texture issues]                     0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.then off]                          -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.thick]                              0.5000      0.456      1.097      0.273      -0.394       1.394
# C(characteristic)[T.toast]                              0.1250      0.456      0.274      0.784      -0.769       1.019
# C(characteristic)[T.tobacco]                            0.0156      0.378      0.041      0.967      -0.725       0.757
# C(characteristic)[T.toffee]                             0.2187      0.395      0.554      0.580      -0.555       0.993
# C(characteristic)[T.too sweet]                         -0.5833      0.402     -1.451      0.147      -1.371       0.205
# C(characteristic)[T.tropical]                           0.3333      0.430      0.776      0.438      -0.509       1.176
# C(characteristic)[T.tropical berry]                     0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.tropical fruit]                     0.2500      0.456      0.548      0.583      -0.644       1.144
# C(characteristic)[T.true to origin]                 -2.095e-12      0.526  -3.98e-12      1.000      -1.032       1.032
# C(characteristic)[T.true to sugar]                     -0.7500      0.456     -1.645      0.100      -1.644       0.144
# C(characteristic)[T.true to sugar bar]                 -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.ultra fruit]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.unbalanced]                        -0.5000      0.456     -1.097      0.273      -1.394       0.394
# C(characteristic)[T.uncontrolled bitter]               -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.undefined]                         -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.under refined]                     -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.uneven]                            -0.3750      0.456     -0.823      0.411      -1.269       0.519
# C(characteristic)[T.uneven melt]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.unique]                             0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.unique flavor]                      0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.unpleasant]                        -1.7500      0.526     -3.325      0.001      -2.782      -0.718
# C(characteristic)[T.unrecognizable]                    -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.unrefined]                         -0.5115      0.386     -1.324      0.185      -1.269       0.246
# C(characteristic)[T.unripened fruit]                    0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.vanilla]                           -0.3563      0.375     -0.951      0.342      -1.090       0.378
# C(characteristic)[T.vanilla dominant]                  -0.8750      0.456     -1.919      0.055      -1.769       0.019
# C(characteristic)[T.vegetal]                           -0.0929      0.377     -0.246      0.806      -0.833       0.647
# C(characteristic)[T.very acidic]                       -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.very astringent]                   -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.very bitter]                       -1.7500      0.456     -3.839      0.000      -2.644      -0.856
# C(characteristic)[T.very bland]                        -1.2500      0.526     -2.375      0.018      -2.282      -0.218
# C(characteristic)[T.very coarse]                        0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.very grass]                         0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.very nut]                          -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.very roast]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.very sandy]                        -0.3750      0.456     -0.823      0.411      -1.269       0.519
# C(characteristic)[T.very smoke]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.very sour]                         -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.very spice]                        -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.very spicy]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.very sweet]                        -0.2500      0.390     -0.640      0.522      -1.015       0.515
# C(characteristic)[T.vinegar]                           -0.5833      0.430     -1.357      0.175      -1.426       0.259
# C(characteristic)[T.walnut]                            -0.0833      0.430     -0.194      0.846      -0.926       0.759
# C(characteristic)[T.watered down coffee]               -0.2500      0.526     -0.475      0.635      -1.282       0.782
# C(characteristic)[T.watery]                          -2.11e-12      0.456  -4.63e-12      1.000      -0.894       0.894
# C(characteristic)[T.waxy]                              -0.2857      0.385     -0.742      0.458      -1.041       0.470
# C(characteristic)[T.well balanced]                      0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.well defined]                       0.7500      0.526      1.425      0.154      -0.282       1.782
# C(characteristic)[T.well developed]                     0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.wet]                               -0.7500      0.526     -1.425      0.154      -1.782       0.282
# C(characteristic)[T.whole bean]                     -2.209e-12      0.526   -4.2e-12      1.000      -1.032       1.032
# C(characteristic)[T.why bother]                        -1.2500      0.526     -2.375      0.018      -2.282      -0.218
# C(characteristic)[T.wild berry]                         0.2500      0.526      0.475      0.635      -0.782       1.282
# C(characteristic)[T.wine]                               0.5000      0.408      1.226      0.220      -0.299       1.299
# C(characteristic)[T.wood]                              -0.0994      0.374     -0.265      0.791      -0.833       0.635
# C(characteristic)[T.woodsy]                             0.1389      0.392      0.354      0.723      -0.630       0.908
# C(characteristic)[T.wtf]                               -1.7500      0.526     -3.325      0.001      -2.782      -0.718
# C(characteristic)[T.xl nibs]                           -0.5000      0.526     -0.950      0.342      -1.532       0.532
# C(characteristic)[T.yellow fruit]                       0.5000      0.526      0.950      0.342      -0.532       1.532
# C(characteristic)[T.yogurt]                             0.0625      0.416      0.150      0.881      -0.753       0.878
# ==============================================================================
# Omnibus:                      174.442   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              233.595
# Skew:                          -0.315   Prob(JB):                     1.89e-51
# Kurtosis:                       3.693   Cond. No.                     2.18e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#ANOVA test for 'bean_country'
anova_df = df_rating[['rating', 'bean_country']].dropna()

relate_df = df_rating[['rating', 'bean_country']]
anova = smf.ols(formula='rating ~ C(bean_country)', data=anova_df).fit()

anova.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.229
# Date:                Wed, 07 Apr 2021   Prob (F-statistic):              0.122
# Time:                        11:46:14   Log-Likelihood:                -1287.7
# No. Observations:                2274   AIC:                             2687.
# Df Residuals:                    2218   BIC:                             3008.
# Df Model:                          55
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    3.2500      0.249     13.042      0.000       2.761       3.739
# C(bean_country)[T.Belize]                                 3.197e-14      0.255   1.26e-13      1.000      -0.500       0.500
# C(bean_country)[T.Bolivia]                                  -0.0642      0.254     -0.253      0.801      -0.563       0.434
# C(bean_country)[T.Brazil]                                  4.03e-14      0.254   1.59e-13      1.000      -0.498       0.498
# C(bean_country)[T.Cameroon]                                 -0.1667      0.352     -0.473      0.636      -0.858       0.524
# C(bean_country)[T.Colombia]                                 -0.0373      0.255     -0.146      0.884      -0.537       0.462
# C(bean_country)[T.Costa Rica]                               -0.0952      0.258     -0.369      0.712      -0.601       0.411
# C(bean_country)[T.Cuba]                                      0.0417      0.279      0.150      0.881      -0.505       0.588
# C(bean_country)[T.Côte d’Ivoire (aka Ivory Coast)]          -0.3500      0.315     -1.110      0.267      -0.968       0.268
# C(bean_country)[T.Democratic Republic of the Congo]         -0.2500      0.498     -0.502      0.616      -1.227       0.727
# C(bean_country)[T.Dominican Republic]                       -0.0398      0.251     -0.158      0.874      -0.532       0.452
# C(bean_country)[T.Ecuador]                                  -0.0379      0.251     -0.151      0.880      -0.530       0.454
# C(bean_country)[T.El Salvador]                              -0.2500      0.305     -0.819      0.413      -0.849       0.349
# C(bean_country)[T.Fiji]                                     -0.1833      0.273     -0.672      0.502      -0.719       0.352
# C(bean_country)[T.Gabon]                                 -4.308e-14      0.498  -8.64e-14      1.000      -0.977       0.977
# C(bean_country)[T.Ghana]                                    -0.0937      0.261     -0.360      0.719      -0.605       0.417
# C(bean_country)[T.Grenada]                                  -0.2353      0.270     -0.871      0.384      -0.765       0.295
# C(bean_country)[T.Guatemala]                                 0.0307      0.256      0.120      0.904      -0.471       0.532
# C(bean_country)[T.Haiti]                                     0.0288      0.263      0.110      0.913      -0.487       0.545
# C(bean_country)[T.Honduras]                                 -0.0217      0.265     -0.082      0.935      -0.541       0.498
# C(bean_country)[T.India]                                    -0.1196      0.265     -0.451      0.652      -0.639       0.400
# C(bean_country)[T.Indonesia]                                -0.0921      0.268     -0.343      0.731      -0.618       0.434
# C(bean_country)[T.Jamaica]                                  -0.0761      0.265     -0.287      0.774      -0.596       0.443
# C(bean_country)[T.Liberia]                                  -0.1667      0.352     -0.473      0.636      -0.858       0.524
# C(bean_country)[T.Madagascar]                                0.0185      0.251      0.074      0.941      -0.475       0.512
# C(bean_country)[T.Malaysia]                                 -0.2143      0.298     -0.719      0.472      -0.798       0.370
# C(bean_country)[T.Martinique (French Territory)]            -0.5000      0.498     -1.003      0.316      -1.477       0.477
# C(bean_country)[T.Mexico]                                   -0.1304      0.257     -0.507      0.612      -0.635       0.374
# C(bean_country)[T.Multiple Countries]                       -0.1679      0.252     -0.666      0.505      -0.662       0.326
# C(bean_country)[T.Myanmar (aka Burma)]                      -0.2500      0.498     -0.502      0.616      -1.227       0.727
# C(bean_country)[T.Nicaragua]                                -0.0080      0.253     -0.032      0.975      -0.504       0.488
# C(bean_country)[T.Nigeria]                                  -0.3750      0.394     -0.952      0.341      -1.148       0.398
# C(bean_country)[T.Panama]                                   -0.0937      0.292     -0.321      0.748      -0.667       0.479
# C(bean_country)[T.Papua New Guinea]                          0.0260      0.257      0.101      0.919      -0.478       0.530
# C(bean_country)[T.Peru]                                     -0.0488      0.251     -0.194      0.846      -0.541       0.443
# C(bean_country)[T.Philippines]                              -0.1447      0.268     -0.540      0.589      -0.671       0.381
# C(bean_country)[T.Puerto Rico (United States Territory)]    -0.5000      0.305     -1.638      0.102      -1.099       0.099
# C(bean_country)[T.Republic of the Congo]                     0.0682      0.281      0.243      0.808      -0.483       0.619
# C(bean_country)[T.Saint Lucia]                              -0.1667      0.288     -0.579      0.563      -0.731       0.398
# C(bean_country)[T.Saint Vincent and the Grenadines]         -0.5000      0.498     -1.003      0.316      -1.477       0.477
# C(bean_country)[T.Samoa]                                    -0.1667      0.352     -0.473      0.636      -0.858       0.524
# C(bean_country)[T.Sao Tome and Principe]                    -0.1719      0.272     -0.633      0.527      -0.704       0.361
# C(bean_country)[T.Sierra Leone]                             -0.5000      0.330     -1.517      0.129      -1.146       0.146
# C(bean_country)[T.Solomon Islands]                           0.2000      0.284      0.704      0.482      -0.357       0.757
# C(bean_country)[T.Sri Lanka]                                -0.3750      0.394     -0.952      0.341      -1.148       0.398
# C(bean_country)[T.Suriname]                               5.596e-14      0.498   1.12e-13      1.000      -0.977       0.977
# C(bean_country)[T.Taiwan]                                   -0.3750      0.394     -0.952      0.341      -1.148       0.398
# C(bean_country)[T.Tanzania]                                 -0.0217      0.255     -0.085      0.932      -0.521       0.477
# C(bean_country)[T.Thailand]                                  0.0500      0.315      0.159      0.874      -0.568       0.668
# C(bean_country)[T.Togo]                                     -0.1667      0.352     -0.473      0.636      -0.858       0.524
# C(bean_country)[T.Trinidad and Tobago]                      -0.0321      0.259     -0.124      0.901      -0.539       0.475
# C(bean_country)[T.Uganda]                                   -0.2500      0.276     -0.904      0.366      -0.792       0.292
# C(bean_country)[T.United States]                            -0.0625      0.262     -0.238      0.812      -0.577       0.452
# C(bean_country)[T.Vanuatu]                                  -0.1875      0.279     -0.673      0.501      -0.734       0.359
# C(bean_country)[T.Venezuela]                                -0.0146      0.251     -0.058      0.953      -0.506       0.477
# C(bean_country)[T.Vietnam]                                   0.0075      0.255      0.029      0.977      -0.492       0.507
# ==============================================================================
# Omnibus:                       49.183   Durbin-Watson:                   1.292
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.034
# Skew:                          -0.355   Prob(JB):                     5.02e-12
# Kurtosis:                       3.211   Cond. No.                         213.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#ANOVA test for 'ingredient_combination'
anova_df = df_rating[['rating', 'ingredient_combination']].dropna()

relate_df = df_rating[['rating', 'ingredient_combination']]
anova = smf.ols(formula='rating ~ C(ingredient_combination)', data=anova_df).fit()

anova.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     6.510
# Date:                Wed, 07 Apr 2021   Prob (F-statistic):           1.38e-17
# Time:                        11:46:14   Log-Likelihood:                -1257.9
# No. Observations:                2274   AIC:                             2558.
# Df Residuals:                    2253   BIC:                             2678.
# Df Model:                          20
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                2.9500      0.189     15.606      0.000       2.579       3.321
# C(ingredient_combination)[T.BC]          0.0500      0.463      0.108      0.914      -0.858       0.958
# C(ingredient_combination)[T.BS]          0.2703      0.190      1.424      0.154      -0.102       0.642
# C(ingredient_combination)[T.BS*]         0.0097      0.204      0.048      0.962      -0.390       0.409
# C(ingredient_combination)[T.BS*C]       -0.0125      0.225     -0.056      0.956      -0.454       0.429
# C(ingredient_combination)[T.BS*CL]      -0.0750      0.354     -0.212      0.832      -0.769       0.619
# C(ingredient_combination)[T.BS*CSa]      0.1625      0.211      0.769      0.442      -0.252       0.577
# C(ingredient_combination)[T.BS*CV]       0.0500      0.248      0.202      0.840      -0.435       0.535
# C(ingredient_combination)[T.BS*Sa]      -0.4500      0.463     -0.972      0.331      -1.358       0.458
# C(ingredient_combination)[T.BS*VL]       0.1333      0.309      0.432      0.666      -0.472       0.739
# C(ingredient_combination)[T.BSC]         0.3260      0.190      1.720      0.086      -0.046       0.698
# C(ingredient_combination)[T.BSCL]        0.2533      0.191      1.328      0.184      -0.121       0.627
# C(ingredient_combination)[T.BSCLSa]      0.0500      0.463      0.108      0.914      -0.858       0.958
# C(ingredient_combination)[T.BSCSa]       0.2000      0.267      0.748      0.454      -0.324       0.724
# C(ingredient_combination)[T.BSCV]        0.0176      0.192      0.092      0.927      -0.360       0.395
# C(ingredient_combination)[T.BSCVL]       0.1397      0.192      0.729      0.466      -0.236       0.515
# C(ingredient_combination)[T.BSCVLSa]    -0.0125      0.284     -0.044      0.965      -0.569       0.544
# C(ingredient_combination)[T.BSCVSa]     -0.1583      0.256     -0.619      0.536      -0.660       0.344
# C(ingredient_combination)[T.BSL]        -0.2625      0.241     -1.089      0.276      -0.735       0.210
# C(ingredient_combination)[T.BSV]         0.2167      0.309      0.702      0.483      -0.389       0.822
# C(ingredient_combination)[T.BSVL]       -0.0500      0.267     -0.187      0.852      -0.574       0.474
# ==============================================================================
# Omnibus:                       44.165   Durbin-Watson:                   1.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.391
# Skew:                          -0.336   Prob(JB):                     8.44e-11
# Kurtosis:                       3.194   Cond. No.                         114.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The varaibles memorable_characteristics and ingredient_combination have a p-value less than 0.05. Therefore, we can reject the null and focus on those two variables during the exploratory analysis. The varible bean_country had a p-value greater than 0.05. Therefore, we cannot reject the null and that varaible wil not be examined during the exploratory analysis.

# %% [markdown]
# ### Statistical Significance for Quantitative Data using Pearson's R

# %%
#Pearson's r test for 'total_ingredients'
print('total_ingredients', pearsonr(df_rating['rating'], df_rating['total_ingredients']))
# Out:
# total_ingredients (-0.09840103412745788, 2.585971529232871e-06)

# %%
#Pearson's r test for 'cocoa_percent'
print('cocoa_percent',pearsonr(df_rating['rating'], df_rating['cocoa_percent']))
# Out:
# cocoa_percent (-0.0788768460323526, 0.00016644387820901796)

# %% [markdown]
# The variables cocoa_percent and total_ingredients have a p-value less than 0.05. Therefore, we can reject the null and focus on those two variables during the exploratory analysis.

# %% [markdown]
# # Conclusions
#
# The variables memorable_characteristics (separated into individual characters in 'characteristic' variable in individual_characteristics.csv), 'cocoa_percent', 'total_ingredients','ingredient_combination', have p-value less than 0.05. Therefore, these variables will be analyzed during the exploratory data analysis. The variable 'bean_country' will not be explored during the exploratory data analysis since it had a p-value greater than 0.05.
#
# ### Sources
# Bhandari, P. (2020, October 23). Understanding normal distributions. Scribbr. Retrieved March 21, 2021, from https://www.scribbr.com/statistics/normal-distribution/
